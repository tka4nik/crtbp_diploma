# %%
import orbipy as op
import numpy as np
from scipy.optimize import bisect
import pickle

from instruments import instruments

# %%
model = op.crtbp3_model('Earth-Moon (default)', integrator=op.dopri5_integrator(), stm=True)
one_thousand_kms = (1-model.L1) / 61.350

# %%
def calculate_next_point_with_same_jacoby_constant(correction, previous_state, cj, previous_alpha_degrees):
    """
    Given a previous point on the contour line of the jacobi constant, find the next point on the same contour line (with the same energy/jacobi constant).
    :param previous_state: previous (or initial) state of hte contour line point
    :param cj: jacobi constant of the contour line
    :param previous_alpha_degrees: angle alpha in degrees, for approximating the direction
    :return: (state, alpha)
    """
    def find_alpha(alpha_degrees):
        """
        Given angle alpha, calculate the corresponding state (polar coordinates) and returns the difference between given jacobi constant and the calculated one
        """
        state = model.get_zero_state().copy()
        x = previous_state[0] + np.cos(np.radians(alpha_degrees))*dr
        z = previous_state[2] + np.sin(np.radians(alpha_degrees))*dr
        state[[0,2]] = x, z
        state[4] = previous_state[4]
        velocity = correction.calc_dv(0, state)
        state += velocity
        cj_new = model.jacobi(state)
        return cj - cj_new

    # Find angle alpha that corresponds to the lowest possible deviation of jacobi constant between current point and next point (as in, finds the alpha that corresponds to the point lying on the contour line)
    res = bisect(find_alpha, previous_alpha_degrees - 40, previous_alpha_degrees + 40, 
        xtol=1e-6, maxiter=100,
        full_output=True)
    
    target_alpha_degrees = res[0]
    print("cj = "+ str(cj) + "; alpha = " + str(target_alpha_degrees))
    r = model.get_zero_state().copy()
    x = previous_state[0] + np.cos(np.radians(target_alpha_degrees))*dr
    z = previous_state[2] + np.sin(np.radians(target_alpha_degrees))*dr
    r[[0, 2]] = x, z
    r += correction.calc_dv(0, r)
    return r, target_alpha_degrees

def calculate_contour_line_of_jakobi_constant(model, initial_state, alpha):
    """
    Given initial state of the zvl, calculate the contour line.
    :param initial_state: usually a point, lying on the Zero Velocity Line
    :param alpha: initial alpha (0 for right side and negative velocity, 180 for left side and positive velocity)
    :return: array of states [ [x,z,vy], [x,z,vy], [x,z,vy], ... ]
    """
    Cj = model.jacobi(initial_state)
    points = []

    points.append(initial_state[[0, 2, 4]].tolist())
    
    left = op.eventX(model.L1 - 33 * one_thousand_kms)
    right = op.eventX(model.L1 + 55 * one_thousand_kms)

    while points[-1][1] > 0: # until we cross the x axis
        correction = op.border_correction(model, op.y_direction(), left, right)
        try:
            next_point_with_same_jakoby_constant, alpha = calculate_next_point_with_same_jacoby_constant(correction, initial_state, Cj, alpha)
        except (RuntimeError, ValueError) as e:
            print(f"next point from {points[-1]} failed! {e}")
            break
        points.append(next_point_with_same_jakoby_constant[[0, 2, 4]].tolist())
        print(f"    point {points[-1]}")
    return points

# %%
data = np.load('../data/contour_points/zvl/zvl_4__0_3_dv.npy')

dr = 0.3*one_thousand_kms
contour_lines_data = []

initial_state_points = np.array(np.meshgrid(np.arange(0, 49), [0, 180])).T.reshape(-1, 2).tolist()
print(initial_state_points)

for point in initial_state_points:
    print(f"Calculating contour line for initial state {point[0]}, {"left" if point[1] == 180 else "right"} side")
    alpha = point[1]
    initial_state = model.get_zero_state()
    initial_state[[0,2]] = data[point[0]][0], data[point[0]][1]
    
    contour_line = calculate_contour_line_of_jakobi_constant(model, initial_state, alpha)
    contour_lines_data.append(contour_line)
    print(contour_line)
    with open("../data/contour_points/contour_points_data_7_points.pickle", 'wb') as handle:
        pickle.dump(contour_lines_data, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:

# eventX:[val]np.float64(0.7491359754271466) [dir]0 [trm]True [acc]True [cnt]-1 eventX:[val]np.float64(0.9831161997240316) [dir]0 [trm]True [acc]True [cnt]-1
# cj = 3.0156285946537538; alpha = -75.33471822738647
# [0.9610647861531052, 0.13875904100497297, -0.29966702252839117]
# eventX:[val]np.float64(0.7491359754271466) [dir]0 [trm]True [acc]True [cnt]-1 eventX:[val]np.float64(0.9831161997240316) [dir]0 [trm]True [acc]True [cnt]-1
# cj = 3.0156285946537538; alpha = -75.59482991695404
# [0.9612632258073026, 0.13798645900362286, -0.3016245338678779]
# eventX:[val]np.float64(0.7491359754271466) [dir]0 [trm]True [acc]True [cnt]-1 eventX:[val]np.float64(0.9831161997240316) [dir]0 [trm]True [acc]True [cnt]-1
# cj = 3.0156285946537538; alpha = -75.85561275482178
# [0.9614581469963976, 0.1372129818060211, -0.3035871618955276]
# eventX:[val]np.float64(0.7491359754271466) [dir]0 [trm]True [acc]True [cnt]-1 eventX:[val]np.float64(0.9831161997240316) [dir]0 [trm]True [acc]True [cnt]-1
# cj = 3.0156285946537538; alpha = -76.11712753772736
# [0.9616495357900435, 0.13643862299071977, -0.3055550897945395]
# eventX:[val]np.float64(0.7491359754271466) [dir]0 [trm]True [acc]True [cnt]-1 eventX:[val]np.float64(0.9831161997240316) [dir]0 [trm]True [acc]True [cnt]-1
# capi_return is NULL
# Call-back cb_solout_in___user__routines failed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 15
#      12 initial_state[[0,2]] = data[point[0]][0], data[point[0]][1]
#      14 new_points = []
# ---> 15 calculate_contour_line_of_jakobi_constant(model, initial_state, alpha, new_points)
#      16 print(new_points)
#      17 points.append(new_points)
#
# Cell In[24], line 42, in calculate_contour_line_of_jakobi_constant(model, initial_state, alpha, points)
#      40 correction = op.border_correction(model, op.y_direction(), left, right)
#      41 try:
# ---> 42     next_point_with_same_jakoby_constant, alpha = calculate_next_point_with_same_jacoby_constant(correction, initial_state, Cj, alpha)
#      43 except (RuntimeError, ValueError) as e:
#      44     print(e, sep=' ')
#
# Cell In[24], line 17, in calculate_next_point_with_same_jacoby_constant(correction, previous_state, cj, previous_alpha_degrees)
#      13     return cj - cj_new
#      15 # print(find_alpha(previous_alpha_degrees-15))
# ---> 17 res = bisect(find_alpha, previous_alpha_degrees - 40, previous_alpha_degrees + 40,
#      18     xtol=1e-6, maxiter=100,
#      19     full_output=True)
#      21 target_alpha_degrees = res[0]
#      22 print("cj = "+ str(cj) + "; alpha = " + str(target_alpha_degrees))
#
# File ~/Workdir/diploma/project/.venv/lib64/python3.12/site-packages/scipy/optimize/_zeros_py.py:577, in bisect(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     575     raise ValueError(f"rtol too small ({rtol:g} < {_rtol:g})")
#     576 f = _wrap_nan_raise(f)
# --> 577 r = _zeros._bisect(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     578 return results_c(full_output, r, "bisect")
#
# File ~/Workdir/diploma/project/.venv/lib64/python3.12/site-packages/scipy/optimize/_zeros_py.py:94, in _wrap_nan_raise.<locals>.f_raise(x, *args)
#      93 def f_raise(x, *args):
# ---> 94     fx = f(x, *args)
#      95     f_raise._function_calls += 1
#      96     if np.isnan(fx):
#
# Cell In[24], line 9, in calculate_next_point_with_same_jacoby_constant.<locals>.find_alpha(alpha_degrees)
#       7 state[4] = previous_state[4]
#       8 # print(state)
# ----> 9 velocity = correction.calc_dv(0, state)
#      10 state += velocity
#      11 cj_new = jacoby_constant(model, state)
#
# File ~/Workdir/diploma/project/.venv/lib/python3.12/site-packages/orbipy/corrections.py:117, in border_correction.calc_dv(self, t, s)
#     115 # root separation
#     116 for i in range(self.iterations[0]):
# --> 117     pa = get_border(-dv)
#     118     pb = get_border( dv)
#     119     if pa == pb:
#
# File ~/Workdir/diploma/project/.venv/lib/python3.12/site-packages/orbipy/corrections.py:110, in border_correction.calc_dv.<locals>.get_border(v)
#     108 else:
#     109     s2 = s1
# --> 110 _, ev = detector.prop(s2, t, t+self.maxt, ret_df=False)
#     111 if ev.shape[0] < 1:
#     112     raise RuntimeError(self.error_borders_unreachable)
#
# File ~/Workdir/diploma/project/.venv/lib/python3.12/site-packages/orbipy/events.py:87, in event_detector.prop(self, s0, t0, t1, ret_df, last_state)
#      85 old_solout, old_solout2 = self.model.solout, self.accurate_model.solout
#      86 self.model.solout = self.solout
# ---> 87 df = self.model.prop(s0, t0, t1, ret_df=False)
#      88 evdf = self.accurate(ret_df=False)
#      89 self.model.solout, self.accurate_model.solout = old_solout, old_solout2
#
# File ~/Workdir/diploma/project/.venv/lib/python3.12/site-packages/orbipy/models.py:401, in crtbp3_model.prop(self, s0, t0, t1, ret_df)
#     374 '''
#     375 Propagate spacecraft from initial state s0 at time t0 up to time t1.
#     376
#    (...)
#     398
#     399 '''
#     400 self._solout.reset()
# --> 401 self.integrator.integrate(self.right_part, s0, t0, t1, fargs=(self._constants,))
#     402 if ret_df:
#     403     return self.to_df(self._solout.out)
#
# File ~/Workdir/diploma/project/.venv/lib/python3.12/site-packages/orbipy/integrators.py:178, in dopri5_integrator.integrate(self, func, s0, t0, t1, fargs)
#     176 self.integrator.set_f_params(*fargs)
#     177 self.integrator.set_initial_value(s0, t0)
# --> 178 return self.integrator.integrate(t1)
#
# File ~/Workdir/diploma/project/.venv/lib64/python3.12/site-packages/scipy/integrate/_ode.py:431, in ode.integrate(self, t, step, relax)
#     428     mth = self._integrator.run
#     430 try:
# --> 431     self._y, self.t = mth(self.f, self.jac or (lambda: None),
#     432                           self._y, self.t, t,
#     433                           self.f_params, self.jac_params)
#     434 except SystemError as e:
#     435     # f2py issue with tuple returns, see ticket 1187.
#     436     raise ValueError(
#     437         'Function to integrate must not return a tuple.'
#     438     ) from e
#
# File ~/Workdir/diploma/project/.venv/lib64/python3.12/site-packages/scipy/integrate/_ode.py:1176, in dopri5.run(self, f, jac, y0, t0, t1, f_params, jac_params)
#    1175 def run(self, f, jac, y0, t0, t1, f_params, jac_params):
# -> 1176     x, y, iwork, istate = self.runner(*((f, t0, y0, t1) +
#    1177                                       tuple(self.call_args) + (f_params,)))
#    1178     self.istate = istate
#    1179     if istate < 0:
#
# File ~/Workdir/diploma/project/.venv/lib64/python3.12/site-packages/scipy/integrate/_ode.py:1191, in dopri5._solout(self, nr, xold, x, y, nd, icomp, con)
#    1189     if self.solout_cmplx:
#    1190         y = y[::2] + 1j * y[1::2]
# -> 1191     return self.solout(x, y)
#    1192 else:
#    1193     return 1
#
# File ~/Workdir/diploma/project/.venv/lib/python3.12/site-packages/orbipy/solout.py:65, in event_solout.__call__(self, t, s)
#      62 self.out.append([t, *s])
#      63 self.evvals.append(cur_evvals)
# ---> 65 for i, event in enumerate(self._events):
#      66     cur_val = cur_evvals[i]
#      67     prev_val = self.evvals[-2][i]
#
# KeyboardInterrupt:

# %%
instruments.ism_contour_visualizer(contour_lines_data).show()
