# %%
import pickle
from instruments import icm_contour_visualizer
from instruments import icm_points_visualizer
from instruments import icm_contour_comparison
from instruments import icm_points_comparison
from instruments import vcsm_contour_visuzalizer
from instruments import apply_vcsm_filter_to_icm_data

# %%
with open(r"../data/contour_points/icm_contour_data_planes.pickle", "rb") as input_file:
    data = pickle.load(input_file)

icm_contour_visualizer(data).show()
# Out:
# /tmp/ipykernel_2514810/2090447962.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   icm_contour_visualizer(data).show()

# %%
with open(r"../data/contour_points/icm_points_data_planes_filtered.pickle", "rb") as input_file:
    points = pickle.load(input_file)

icm_points_visualizer(points).show()
# Out:
# /tmp/ipykernel_2514810/729732576.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   icm_points_visualizer(points).show()

# %%
with open(r"../data/contour_points/icm_points_data_planes_filtered.pickle", "rb") as input_file_1:
    points_planes = pickle.load(input_file_1)
with open(r"../data/contour_points/icm_points_data_spl_filtered.pickle", "rb") as input_file_2:
    points_spl = pickle.load(input_file_2)

icm_points_comparison(points_spl, points_planes, "Метод вращения", "Метод плоскостей").show()
# Out:
# /tmp/ipykernel_2514810/3184762035.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   icm_points_comparison(points_spl, points_planes, "Метод вращения", "Метод плоскостей").show()

# %%
with open(r"../data/contour_points/sumdv_maps/vcsm_contour_data_planes.pickle", "rb") as input_file:
    data = pickle.load(input_file)

vcsm_contour_visuzalizer(data).show()
# Out:
# /tmp/ipykernel_2514810/2258845671.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   vcsm_contour_visuzalizer(data).show()

# %%
with open(r"../data/contour_points/sumdv_maps/vcsm_contour_data_planes.pickle", "rb") as input_file:
    data = pickle.load(input_file)

vcsm_contour_visuzalizer(data, show_fails=False).show()
# Out:
# /tmp/ipykernel_2514810/1745147516.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   vcsm_contour_visuzalizer(data, show_fails=False).show()

# %%
with open(r"../data/contour_points/sumdv_maps/vcsm_contour_data_planes.pickle", "rb") as input_file:
    data = pickle.load(input_file)

vcsm_contour_visuzalizer(data, filter=True).show()
# Out:
# /tmp/ipykernel_2514810/2235164069.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   vcsm_contour_visuzalizer(data, filter=True).show()

# %%
with open(r"../data/contour_points/sumdv_maps/vcsm_contour_data_planes.pickle", "rb") as input_file:
    vcsm_data = pickle.load(input_file)

with open(r"../data/contour_points/icm_contour_data_planes.pickle", "rb") as input_file:
    icm_data = pickle.load(input_file)[:229] # :229 due to the fact that i did the vcsm check selectively and not for all points

filtered_icm_points = apply_vcsm_filter_to_icm_data(vcsm_data, icm_data)

icm_contour_visualizer(filtered_icm_points).show()
# Out:
# /tmp/ipykernel_2514810/1504895233.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   icm_points_visualizer(filtered_icm_points).show()
